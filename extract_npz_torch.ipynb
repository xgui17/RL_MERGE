# %%
import torch

model_path = "data/E122/saved_runs/model_2024-10-28-at-19-33-56.pt"
model = torch.load(model_path)

print(model)
# Out:
# OrderedDict({'conv1.lin_l.weight': tensor([[-0.2690, -0.1847, -0.2530,  ..., -0.0908,  0.0879,  0.2361],
#         [ 0.1375, -0.0013, -0.0552,  ..., -0.0159, -0.1180, -0.1076],
#         [-0.0276, -0.0178, -0.0416,  ...,  0.2796, -0.0816, -0.0218],
#         ...,
#         [-0.3094,  0.2855, -0.1672,  ...,  0.0518, -0.0404,  0.0317],
#         [ 0.2597,  0.0500, -0.2494,  ...,  0.2292,  0.0924,  0.1122],
#         [-0.0016,  0.0217,  0.2123,  ..., -0.0902, -0.2273, -0.1803]],
#        device='cuda:0'), 'conv1.lin_l.bias': tensor([ 0.1802, -0.1422, -0.0075, -0.1919,  0.0731, -0.0099,  0.0875, -0.0127,
#          0.1158, -0.0292,  0.2346, -0.0919,  0.2368,  0.0011,  0.0409, -0.1110,
#         -0.1769, -0.1543, -0.1911,  0.1714,  0.1378,  0.0003,  0.1488,  0.0930,
#          0.2418,  0.2530,  0.2734, -0.1221,  0.2462, -0.2131,  0.1020, -0.1716,
#          0.2007,  0.0304, -0.1860,  0.0609, -0.1413,  0.2516, -0.0117, -0.2348,
# ...

# %%
import numpy as np

# %%
npz_path = "data/E122/saved_runs/model_2024-10-28-at-19-33-56_test_metrics.npz"
data = np.load(npz_path)

print(data.files)
# Out:
# ['test_gene_ID', 'test_pred', 'test_labels', 'test_pearson_vec', 'test_loss_vec']

# %%
array_name = data.files[1]
print(data[array_name])
# Out:
# [0.67604584 0.2114237  0.01556507 ... 0.03649754 0.03697712 1.4499558 ]
